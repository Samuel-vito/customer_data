# %%
print("hello")
# Out:
# hello

# %%
import timeit
import matplotlib.pyplot as plt
def Input(Array,n):
    for i in range(0,n):
        ele=int(input("Arr:"))
        Array.append(ele)
def linear_search(Array,key):
    for x in Array:
        if x==key:
            return True
    return False
N=[]
CPU=[]
trial=int(input("Enter no.of trials:"))   
for t in range(0,trial):
    Array=[]
    print("----->TRAIL NO:",t+1)
    n=int(input("Enter number of elements:"))
    Input(Array,n) 
    print(Array)
    key=int(input("Enter Key:"))
    start=timeit.default_timer()
    s=linear_search(Array,key)
    print("Elements Found=",s)
    times=timeit.default_timer()-start
    N.append(n)
    CPU.append(round(float(times)*1000000,2))
print("N CPU")
for t in range(0,trial):
    print(N[t],CPU[t])

plt.plot(N,CPU)
plt.scatter(N,CPU,color="red",marker="*",s=50)
plt.xlabel('Array Size-N')
plt.ylabel('CPU Processing Time')
plt.title('Linear Search Time efficincy')
plt.show()
# Out:
# Enter no.of trials: 3
# ----->TRAIL NO: 1
# Enter number of elements: 3
# Arr: 89
# Arr: 76
# Arr: 56
# [89, 76, 56]
# Enter Key: 56
# Elements Found= True
# ----->TRAIL NO: 2
# Enter number of elements: 4
# Arr: 8
# Arr: 6
# Arr: 9
# Arr: 2
# [8, 6, 9, 2]
# Enter Key: 8
# Elements Found= True
# ----->TRAIL NO: 3
# Enter number of elements: 9
# Arr: 67
# Arr: 6
# Arr: 89
# Arr: 73
# Arr: 40
# Arr: 81
# Arr: 39
# Arr: 73
# Arr: 92
# [67, 6, 89, 73, 40, 81, 39, 73, 92]
# Enter Key: 73
# Elements Found= True
# N CPU
# 3 221.0
# 4 251.0
# 9 220.0
